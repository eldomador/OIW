# %%
import numpy as np

# %%
import pandas as pd

# %%
fury=pd.read_csv('samochody1tys.csv')

# %%
# Statystyki samochody1tys.csv

# %%
fury.describe()
# Out:
#                 id  rok_produkcji  pojemnosc_silnika       przebieg  \
# count  1000.000000    1000.000000        1000.000000    1000.000000
# mean    499.500000    2009.009000        2040.065000  132556.677000
# std     288.819436       5.907946        6014.545066   90094.944138
# min       0.000000    1979.000000           1.000000       1.000000
# 25%     249.750000    2005.000000        1500.000000   51750.000000
# 50%     499.500000    2009.000000        1800.000000  149000.000000
# 75%     749.250000    2014.000000        2000.000000  193000.000000
# max     999.000000    2017.000000      191000.000000  647000.000000
#
#                 cena
# count    1000.000000
# mean    51942.181000
# std     70057.918015
# min       650.000000
# 25%     14900.000000
# 50%     27250.000000
# 75%     58900.000000
# max    616000.000000

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
#5 pierwszych rekordów

# %%
fury.head()
# Out:
#    id       marka        model  rok_produkcji rodzaj_silnika  \
# 0   0      Nissan  X-Trail III         2014.0         Diesel
# 1   1         BMW       X1 E84         2012.0         Diesel
# 2   2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3   3     Hyundai        i10 I         2008.0        Benzyna
# 4   4  Volkswagen           CC         2010.0         Diesel
#
#    pojemnosc_silnika  przebieg     cena     wojewodztwo
# 0             1600.0  160000.0  75900.0    Dolnośląskie
# 1             2000.0  149000.0  70900.0  Świętokrzyskie
# 2             1600.0   99000.0   9800.0        Opolskie
# 3             1100.0   93000.0  11900.0         Łódzkie
# 4             1968.0  127428.0  49900.0   Wielkopolskie

# %%
# 5 ostatnich rekordów

# %%
fury.tail()
# Out:
#       id       marka     model  rok_produkcji rodzaj_silnika  \
# 995  995  Alfa Romeo       159         2009.0         Diesel
# 996  996       Škoda  Fabia II         2012.0        Benzyna
# 997  997     Renault     Modus         2004.0        Benzyna
# 998  998        Audi     A3 8L         2000.0        Benzyna
# 999  999       Volvo   XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena  wojewodztwo
# 995             2387.0  182000.0   33900.0  Małopolskie
# 996             1200.0   42700.0   25400.0    Lubelskie
# 997             1200.0  168111.0   10900.0      Łódzkie
# 998             1595.0  226500.0    5400.0  Małopolskie
# 999             1969.0   13617.0  136900.0  Małopolskie

# %%
# skruktura indexów

# %%
fury.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# stróktóra kolumn

# %%
fury.columns
# Out:
# Index(['id', 'marka', 'model', 'rok_produkcji', 'rodzaj_silnika',
#        'pojemnosc_silnika', 'przebieg', 'cena', 'wojewodztwo'],
#       dtype='object')

# %%
# zamiana na tablice

# %%
fury.to_numpy()
# Out:
# array([[0, 'Nissan', 'X-Trail III', ..., 160000.0, 75900.0,
#         'Dolnośląskie'],
#        [1, 'BMW', 'X1 E84', ..., 149000.0, 70900.0, 'Świętokrzyskie'],
#        [2, 'Opel', 'Zafira A', ..., 99000.0, 9800.0, 'Opolskie'],
#        ...,
#        [997, 'Renault', 'Modus', ..., 168111.0, 10900.0, 'Łódzkie'],
#        [998, 'Audi', 'A3 8L', ..., 226500.0, 5400.0, 'Małopolskie'],
#        [999, 'Volvo', 'XC 60 I', ..., 13617.0, 136900.0, 'Małopolskie']],
#       dtype=object)

# %%
# pierwsze 10 i 10 ostatnich

# %%
fury.T
# Out:
#                             0               1            2        3    \
# id                            0               1            2        3
# marka                    Nissan             BMW         Opel  Hyundai
# model               X-Trail III          X1 E84     Zafira A    i10 I
# rok_produkcji              2014            2012         2004     2008
# rodzaj_silnika           Diesel          Diesel  Benzyna+CNG  Benzyna
# pojemnosc_silnika          1600            2000         1600     1100
# przebieg                 160000          149000        99000    93000
# cena                      75900           70900         9800    11900
# wojewodztwo        Dolnośląskie  Świętokrzyskie     Opolskie  Łódzkie
#
#                              4            5             6          7    \
# id                             4            5             6          7
# marka                 Volkswagen         Fiat        Nissan       Seat
# ...

# %%
# sortowanie względem osi

# %%
fury.sort_index(axis=1, ascending=False)
# Out:
#              wojewodztwo  rok_produkcji rodzaj_silnika  przebieg  \
# 0           Dolnośląskie         2014.0         Diesel  160000.0
# 1         Świętokrzyskie         2012.0         Diesel  149000.0
# 2               Opolskie         2004.0    Benzyna+CNG   99000.0
# 3                Łódzkie         2008.0        Benzyna   93000.0
# 4          Wielkopolskie         2010.0         Diesel  127428.0
# 5                Śląskie         2014.0    Elektryczny   36800.0
# 6           Dolnośląskie         2004.0         Diesel  174000.0
# 7              Pomorskie         2000.0        Benzyna  140700.0
# 8              Pomorskie         2014.0         Diesel   52000.0
# 9            Mazowieckie         2016.0        Benzyna   18000.0
# 10              Lubuskie         2015.0        Benzyna   26415.0
# 11           Mazowieckie         2002.0         Diesel  254900.0
# 12           Małopolskie         2014.0        Benzyna   59000.0
# ...

# %%
fury.sort_index(axis=0, ascending=False)
# Out:
#       id          marka          model  rok_produkcji rodzaj_silnika  \
# 999  999          Volvo        XC 60 I         2016.0         Diesel
# 998  998           Audi          A3 8L         2000.0        Benzyna
# 997  997        Renault          Modus         2004.0        Benzyna
# 996  996          Škoda       Fabia II         2012.0        Benzyna
# 995  995     Alfa Romeo            159         2009.0         Diesel
# 994  994           Fiat       Bravo II         2007.0         Diesel
# 993  993           Fiat        Tipo II         2017.0        Benzyna
# 992  992        Renault        Clio IV         2017.0        Benzyna
# 991  991      Chevrolet          Cruze         2010.0        Benzyna
# 990  990  Mercedes-Benz   Klasa S W126         1986.0    Benzyna+LPG
# 989  989            BMW    Seria 5 E39         2002.0         Diesel
# 988  988            BMW             M2         2017.0        Benzyna
# 987  987         Toyota          Camry         1992.0        Benzyna
# ...

# %%
# sortowanie po markach

# %%
fury.sort_values(by='marka')
# Out:
#       id       marka        model  rok_produkcji rodzaj_silnika  \
# 370  370  Alfa Romeo          159         2007.0         Diesel
# 300  300  Alfa Romeo          147         2002.0        Benzyna
# 705  705  Alfa Romeo       Spider         1995.0    Benzyna+LPG
# 213  213  Alfa Romeo          156         2004.0         Diesel
# 995  995  Alfa Romeo          159         2009.0         Diesel
# 643  643        Audi          RS6         2015.0        Benzyna
# 103  103        Audi        A4 B7         2007.0         Diesel
# 60    60        Audi        Q7 II         2016.0         Diesel
# 739  739        Audi        A4 B6         2002.0        Benzyna
# 318  318        Audi        A6 C5         2001.0    Benzyna+LPG
# 715  715        Audi        A4 B7         2006.0        Benzyna
# 93    93        Audi        A4 B6         2001.0        Benzyna
# 331  331        Audi           Q3         2015.0         Diesel
# 709  709        Audi        A4 B7         2007.0         Diesel
# ...

# %%
# tablica marek

# %%
fury['marka']
# Out:
# 0             Nissan
# 1                BMW
# 2               Opel
# 3            Hyundai
# 4         Volkswagen
# 5               Fiat
# 6             Nissan
# 7               Seat
# 8         Volkswagen
# 9             Nissan
# 10            Toyota
# 11               BMW
# 12        Volkswagen
# 13              Audi
# 14               BMW
# 15           Citroën
# 16              Ford
# 17     Mercedes-Benz
# 18        Volkswagen
# 19     Mercedes-Benz
# 20             Honda
# 21     Mercedes-Benz
# 22         Chevrolet
# 23             Volvo
# 24             Volvo
# 25               BMW
# 26             Volvo
# 27               BMW
# 28            Toyota
# 29              Opel
#            ...
# 970           Toyota
# 971    Mercedes-Benz
# 972           Nissan
# 973           Nissan
# 974            Lexus
# 975             Opel
# 976    Mercedes-Benz
# 977          Renault
# 978            Škoda
# 979    Mercedes-Benz
# 980              BMW
# 981             Opel
# ...

# %%
# samochody od 0-2

# %%
fury[0:3]
# Out:
#    id   marka        model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 0   0  Nissan  X-Trail III         2014.0         Diesel             1600.0
# 1   1     BMW       X1 E84         2012.0         Diesel             2000.0
# 2   2    Opel     Zafira A         2004.0    Benzyna+CNG             1600.0
#
#    przebieg     cena     wojewodztwo
# 0  160000.0  75900.0    Dolnośląskie
# 1  149000.0  70900.0  Świętokrzyskie
# 2   99000.0   9800.0        Opolskie

# %%
#

# %%
fury.loc[0:20, ['id', 'marka']]
# Out:
#     id          marka
# 0    0         Nissan
# 1    1            BMW
# 2    2           Opel
# 3    3        Hyundai
# 4    4     Volkswagen
# 5    5           Fiat
# 6    6         Nissan
# 7    7           Seat
# 8    8     Volkswagen
# 9    9         Nissan
# 10  10         Toyota
# 11  11            BMW
# 12  12     Volkswagen
# 13  13           Audi
# 14  14            BMW
# 15  15        Citroën
# 16  16           Ford
# 17  17  Mercedes-Benz
# 18  18     Volkswagen
# 19  19  Mercedes-Benz
# 20  20          Honda

# %%
# wyciągniecie samochodu o id 3

# %%
fury.iloc[3]
# Out:
# id                         3
# marka                Hyundai
# model                  i10 I
# rok_produkcji           2008
# rodzaj_silnika       Benzyna
# pojemnosc_silnika       1100
# przebieg               93000
# cena                   11900
# wojewodztwo          Łódzkie
# Name: 3, dtype: object

# %%
# wypisanie id i marki  o id 3-6

# %%
fury.iloc[3:7, 0:2]
# Out:
#    id       marka
# 3   3     Hyundai
# 4   4  Volkswagen
# 5   5        Fiat
# 6   6      Nissan

# %%
# wypisanie wszytkich iforamcji o samochodach 1-5

# %%
fury.iloc[1:6, :]
# Out:
#    id       marka     model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 1   1         BMW    X1 E84         2012.0         Diesel             2000.0
# 2   2        Opel  Zafira A         2004.0    Benzyna+CNG             1600.0
# 3   3     Hyundai     i10 I         2008.0        Benzyna             1100.0
# 4   4  Volkswagen        CC         2010.0         Diesel             1968.0
# 5   5        Fiat       500         2014.0    Elektryczny                1.0
#
#    przebieg     cena     wojewodztwo
# 1  149000.0  70900.0  Świętokrzyskie
# 2   99000.0   9800.0        Opolskie
# 3   93000.0  11900.0         Łódzkie
# 4  127428.0  49900.0   Wielkopolskie
# 5   36800.0  74200.0         Śląskie

# %%
# wszyystkie samochody z trzema pierwszymi kolumnami

# %%
fury.iloc[:, 1:3]
# Out:
#              marka          model
# 0           Nissan    X-Trail III
# 1              BMW         X1 E84
# 2             Opel       Zafira A
# 3          Hyundai          i10 I
# 4       Volkswagen             CC
# 5             Fiat            500
# 6           Nissan      X-Trail I
# 7             Seat      Toledo II
# 8       Volkswagen             CC
# 9           Nissan           Juke
# 10          Toyota  Corolla Seria
# 11             BMW    Seria 5 E39
# 12      Volkswagen       Jetta A6
# 13            Audi             A1
# 14             BMW    Seria 3 E90
# 15         Citroën   C4 Picasso I
# 16            Ford     Mondeo Mk3
# 17   Mercedes-Benz   Klasa E W213
# 18      Volkswagen      Tiguan II
# 19   Mercedes-Benz        GLK GLK
# 20           Honda        CR-V IV
# 21   Mercedes-Benz   Klasa E W213
# 22       Chevrolet        Captiva
# 23           Volvo            V50
# 24           Volvo         S40 II
# 25             BMW    Seria 3 E46
# ...

# %%
# watrtość z kolumny 1 i wiersza 1

# %%
fury.iloc[1, 1]
# Out:
# 'BMW'

# %%
fury.iat[1, 1]
# Out:
# 'BMW'

# %%
# wszystkie samochody po 2016

# %%
fury[fury.rok_produkcji > 2016]
# Out:
#       id          marka                 model  rok_produkcji rodzaj_silnika  \
# 17    17  Mercedes-Benz          Klasa E W213         2017.0         Diesel
# 18    18     Volkswagen             Tiguan II         2017.0         Diesel
# 20    20          Honda               CR-V IV         2017.0        Benzyna
# 21    21  Mercedes-Benz          Klasa E W213         2017.0         Diesel
# 32    32         Suzuki           SX4 S-Cross         2017.0        Benzyna
# 33    33  Mercedes-Benz               CLA CLA         2017.0        Benzyna
# 36    36            BMW                X5 F15         2017.0         Diesel
# 42    42         Nissan            Qashqai II         2017.0        Benzyna
# 43    43          Volvo                 XC 60         2017.0         Diesel
# 58    58           Ford             Focus Mk3         2017.0        Benzyna
# 71    71         Nissan           X-Trail III         2017.0         Diesel
# ...

# %%
# samochody z 2015

# %%
fury[fury.rok_produkcji == 2015]
# Out:
#       id          marka            model  rok_produkcji rodzaj_silnika  \
# 10    10         Toyota    Corolla Seria         2015.0        Benzyna
# 144  144           Audi            Q5 8R         2015.0         Diesel
# 145  145            BMW      Seria 3 F30         2015.0         Diesel
# 158  158           Ford        Focus Mk3         2015.0         Diesel
# 176  176        Renault  Grand Scenic IV         2015.0         Diesel
# 179  179           Audi            A4 B8         2015.0         Diesel
# 253  253        Hyundai           i20 II         2015.0         Diesel
# 285  285          Škoda        Fabia III         2015.0    Benzyna+LPG
# 330  330     Volkswagen         Jetta A6         2015.0         Diesel
# 331  331           Audi               Q3         2015.0         Diesel
# 333  333        Renault           Kadjar         2015.0         Diesel
# 398  398           Opel          Astra J         2015.0         Diesel
# ...

# %%
# zmiana wartości na 0 dla 0 id na kolumy 1

# %%
fury.iat[0, 1] = 0

# %%
fury
# Out:
#       id          marka          model  rok_produkcji rodzaj_silnika  \
# 0      0              0    X-Trail III         2014.0         Diesel
# 1      1            BMW         X1 E84         2012.0         Diesel
# 2      2           Opel       Zafira A         2004.0    Benzyna+CNG
# 3      3        Hyundai          i10 I         2008.0        Benzyna
# 4      4     Volkswagen             CC         2010.0         Diesel
# 5      5           Fiat            500         2014.0    Elektryczny
# 6      6         Nissan      X-Trail I         2004.0         Diesel
# 7      7           Seat      Toledo II         2000.0        Benzyna
# 8      8     Volkswagen             CC         2014.0         Diesel
# 9      9         Nissan           Juke         2016.0        Benzyna
# 10    10         Toyota  Corolla Seria         2015.0        Benzyna
# 11    11            BMW    Seria 5 E39         2002.0         Diesel
# 12    12     Volkswagen       Jetta A6         2014.0        Benzyna
# ...

# %%
# podaje średnie dla kolumn

# %%
fury.mean()
# Out:
# id                      499.500
# rok_produkcji          2009.009
# pojemnosc_silnika      2040.065
# przebieg             132556.677
# cena                  51942.181
# dtype: float64

# %%
#

# %%
fury.mean(1)
# Out:
# 0      47902.8
# 1      44782.6
# 2      22481.2
# 3      21602.2
# 4      36262.0
# 5      22604.0
# 6      40282.0
# 7      30531.4
# 8      30598.0
# 9      15624.4
# 10     16553.8
# 11     55482.6
# 12     24465.2
# 13     26684.6
# 14     55603.8
# 15     40435.6
# 16     38243.8
# 17     52539.6
# 18     26588.0
# 19     36434.8
# 20     23128.4
# 21     59358.0
# 22     49603.6
# 23     40106.8
# 24     51126.2
# 25     47805.2
# 26     49006.0
# 27     47579.8
# 28     43587.4
# 29     42987.8
#         ...
# 970    20272.8
# 971    92711.8
# 972    33416.8
# 973    38484.0
# 974    41528.2
# 975    37874.6
# 976    34853.2
# 977    17767.4
# 978    21053.2
# 979    30576.2
# 980    39377.0
# 981    37836.6
# 982    59921.6
# 983    40228.8
# 984    32896.6
# 985    15954.0
# 986    28578.8
# 987    31815.2
# 988    56392.0
# 989    84963.4
# 990    72615.2
# 991     6811.8
# 992    12381.6
# 993    10352.4
# 994    48202.2
# 995    44258.2
# 996    14461.6
# 997    36642.4
# ...

# %%
# Sumuje wszystko

# %%
fury.apply(np.cumsum)
# Out:
#          id                                              marka  \
# 0         0                                             Nissan
# 1         1                                          NissanBMW
# 2         3                                      NissanBMWOpel
# 3         6                               NissanBMWOpelHyundai
# 4        10                     NissanBMWOpelHyundaiVolkswagen
# 5        15                 NissanBMWOpelHyundaiVolkswagenFiat
# 6        21           NissanBMWOpelHyundaiVolkswagenFiatNissan
# 7        28       NissanBMWOpelHyundaiVolkswagenFiatNissanSeat
# 8        36  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 9        45  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 10       55  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 11       66  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 12       78  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 13       91  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# ...

# %%
# losowanie 10 liczb od 0-7

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    2
# 1    3
# 2    3
# 3    2
# 4    0
# 5    4
# 6    6
# 7    6
# 8    5
# 9    4
# dtype: int32

# %%
fury = pd.DataFrame(np.random.randn(10, 4))

# %%
# losowe numery w tab4x10

# %%
fury
# Out:
#           0         1         2         3
# 0 -0.537133  1.428631  0.436231  1.157718
# 1 -0.201412  0.369161 -1.190321  0.227647
# 2  0.565969  1.552882  0.301743  1.124423
# 3  0.448692  0.965340 -0.211626  0.060113
# 4 -1.138726  1.648980  0.708878 -0.518660
# 5 -0.221622  0.963437 -1.110922 -0.441753
# 6  1.542972  1.055895  2.265913  1.086505
# 7 -2.869950  0.321083  1.409050  0.002939
# 8  0.443300 -0.513090 -0.022017  1.098188
# 9 -0.871522  0.242525  0.984927  0.208844

# %%
fury.groupby('id').sum()
# Out:
#      rok_produkcji  pojemnosc_silnika  przebieg      cena
# id
# 0           2014.0             1600.0  160000.0   75900.0
# 1           2012.0             2000.0  149000.0   70900.0
# 2           2004.0             1600.0   99000.0    9800.0
# 3           2008.0             1100.0   93000.0   11900.0
# 4           2010.0             1968.0  127428.0   49900.0
# 5           2014.0                1.0   36800.0   74200.0
# 6           2004.0             2200.0  174000.0   23200.0
# 7           2000.0             1800.0  140700.0    8150.0
# 8           2014.0             1968.0   52000.0   97000.0
# 9           2016.0             1197.0   18000.0   56900.0
# 10          2015.0             1329.0   26415.0   53000.0
# 11          2002.0             3000.0  254900.0   17500.0
# 12          2014.0             1400.0   59000.0   59900.0
# 13          2011.0             1400.0   90000.0   39999.0
# 14          2008.0             1998.0  246000.0   27999.0
# ...

# %%
# nowa tabela

# %%
fury = pd.DataFrame({'marka': ['VW']*3,'model': ['Golf', 'Pasat', 'Tiguan'],})

# %%
fury
# Out:
#   marka   model
# 0    VW    Golf
# 1    VW   Pasat
# 2    VW  Tiguan

# %%
# Tabela z czasem

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06    0.358134
# 2012-03-07   -0.199192
# 2012-03-08   -1.828927
# 2012-03-09   -0.342776
# 2012-03-10    0.567688
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')

# %%
 ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    0.358134
# 2012-03-07 00:00:00+00:00   -0.199192
# 2012-03-08 00:00:00+00:00   -1.828927
# 2012-03-09 00:00:00+00:00   -0.342776
# 2012-03-10 00:00:00+00:00    0.567688
# Freq: D, dtype: float64

# %%
# katygorie

# %%
df = pd.DataFrame({"id": [1, 2, 3, 4, 5, 6],
   .....:                    "raw_grade": ['a', 'b', 'b', 'a', 'a', 'e']})

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
 ts = pd.Series(np.random.randn(1000),
   .....:                index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
   .....:                   columns=['A', 'B', 'C', 'D'])

# %%
df = df.cumsum()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()

# %%
df.plot()

# %%
plt.legend(loc='best')
# Out:
# No handles with labels found to put in legend.
